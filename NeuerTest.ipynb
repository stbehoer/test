# %%
import pandas as pd
import numpy as np

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt
import seaborn as sns

import graphviz
import pydotplus
import io
from scipy import misc

import imageio
import ipywidgets as widgets

# %matplotlib inline

# %%
data = pd.read_csv('spotifydata.csv')

# %%
train, test = train_test_split(data, test_size = 0.15)

features = ["danceability", "tempo", "loudness", "instrumentalness", "valence", "energy", "acousticness", "key", "speechiness", "duration_ms"]

# %% [markdown]
# # Machine Learning Demonstrator

# %% [markdown]
# ## Demonstrator Beschreibung
# Lorem ipsum dolor sit amet, consectetuer adipiscing elit, sed diam nonummy nibh euismod tincidunt ut laoreet dolore magna aliquam erat volutpat. Ut wisi enim ad minim veniam, quis nostrud exerci tation ullamcorper suscipit lobortis nisl ut aliquip ex ea commodo consequat. Lorem ipsum dolor sit amet, consectetuer adipiscing elit, sed diam nonummy nibh euismod tincidunt ut laoreet dolore magna aliquam erat volutpat. Ut wisi enim ad minim veniam, quis nostrud exerci tation ullamcorper suscipit lobortis nisl ut aliquip ex ea commodo consequat.

# %% [markdown]
# ## Begriffserklärungen
# #### - Tool Control Center:
#
# Lorem ipsum dolor sit amet, consectetuer adipiscing elit, sed diam nonummy nibh euismod tincidunt ut laoreet dolore magna aliquam erat volutpat. Ut wisi enim ad minim veniam, quis nostrud exerci tation ullamcorper suscipit lobortis nisl ut aliquip ex ea commodo consequat.
#
# #### - Spindel:
#
# Lorem ipsum dolor sit amet, consectetuer adipiscing elit, sed diam nonummy nibh euismod tincidunt ut laoreet dolore magna aliquam erat volutpat. Ut wisi enim ad minim veniam, quis nostrud exerci tation ullamcorper suscipit lobortis nisl ut aliquip ex ea commodo consequat.
#
# #### - Vorschub
# #### - Machine Learning
# #### - Algorithmus xyz

# %%
from bqplot import pyplot as plt2
import ipywidgets as widgets
import numpy as np

# %%
n = 2000
x = np.linspace(0.0, 10.0, n)
np.random.seed(0)
y = np.cumsum(np.random.randn(n)*10).astype(int)

# %%
fig_hist = plt2.figure( title='Histogram Beispieldaten')
hist = plt2.hist(y, bins=25)
fig_hist
# Out:
# Figure(axes=[Axis(orientation='vertical', scale=LinearScale()), Axis(scale=LinearScale())], fig_margin={'top':…

# %%
slider = widgets.IntSlider(min=1, max=100, v_model=30)
slider
# Out:
# IntSlider(value=1, min=1)

# %%
widgets.link((hist, 'bins'), (slider, 'value'));

# %%
fig_lines = plt2.figure( title='Line Chart')
lines = plt2.plot(x, y)
fig_lines
# Out:
# Figure(axes=[Axis(scale=LinearScale()), Axis(orientation='vertical', scale=LinearScale())], fig_margin={'top':…

# %% [markdown]
# ## Decision Tree
#
# Lorem ipsum dolor sit amet, consectetuer adipiscing elit, sed diam nonummy nibh euismod tincidunt ut laoreet dolore magna aliquam erat volutpat. Ut wisi enim ad minim veniam, quis nostrud exerci tation ullamcorper suscipit lobortis nisl ut aliquip ex ea commodo consequat. Lorem ipsum dolor sit amet, consectetuer adipiscing elit, sed diam nonummy nibh euismod tincidunt ut laoreet dolore magna aliquam erat volutpat. Ut wisi enim ad minim veniam, quis nostrud exerci tation ullamcorper suscipit lobortis nisl ut aliquip ex ea commodo consequat.

# %%
c = DecisionTreeClassifier(min_samples_split=400)

X_train = train[features]
Y_train = train["target"]

X_test = test[features]
Y_test = test["target"]

dt = c.fit(X_train, Y_train)

def show_tree(tree, features, path): 
    f = io.StringIO()
    export_graphviz(tree, out_file=f, feature_names=features, class_names=['0', '1'], filled=True)
    pydotplus.graph_from_dot_data(f.getvalue()).write_png(path)
    img = imageio.imread(path)
    plt.rcParams["figure.figsize"] = (20, 20)
    plt.imshow(img)

# %%
show_tree(dt, features, 'dec_tree_03.png')

# %% [markdown]
# ## Interaktives Plotten

# %%
w1 =widgets.Select(
    options=['Vorschub', 'Toleranz', 'xyz'],
    value='Vorschub',
    # rows=10,
    description='x-Achse:',
    disabled=False
)

w2 =widgets.Select(
    options=['Vorschub', 'Toleranz', 'xyz'],
    value='Toleranz',
    # rows=10,
    description='y-Achse:',
    disabled=False
)

display(w1, w2)
# Out:
# Select(description='x-Achse:', options=('Vorschub', 'Toleranz', 'xyz'), value='Vorschub')
# Select(description='y-Achse:', index=1, options=('Vorschub', 'Toleranz', 'xyz'), value='Toleranz')

# %%
from pylab import rcParams
plt.rcParams['figure.figsize'] = (10,5)
data.plot(x='energy', y='loudness', style='o')  
plt.title('Vorschub - Toleranz')  
plt.xlabel('Höhe Vorschub')  
plt.ylabel('Toleranz Abweichung')  

plt.show()
